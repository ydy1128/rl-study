# %%
import numpy as np
import pandas as pd
import random
from collections import defaultdict
import gym
import gym_minigrid
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
class QLearning:
    def __init__(self, actions, agent_indicator=10):
        self.actions = actions
        self.agent_indicator = agent_indicator
        self.alpha = 0.01
        self.gamma = 0.9
        self.epsilon = 0.2
        self.q_values = defaultdict(lambda: [0.0] * actions)
        
    def _convert_state(self, s):
        return np.where(s == self.agent_indicator)[0][0]
        
    def update(self, state, action, reward, next_state, next_action):
        state = self._convert_state(state)
        next_state = self._convert_state(next_state)
        
        q_value = self.q_values[state][action]
        next_q_value = max(self.q_values[next_state])
        
        td_error = reward + self.gamma * next_q_value - q_value
        self.q_values[state][action] = q_value + self.alpha * td_error
    
    def act(self, state):
        if np.random.rand() < self.epsilon:
            action = np.random.choice(self.actions)
        else:
            state = self._convert_state(state)
            q_values = self.q_values[state]
            action = np.argmax(q_values)
        return action

# %%
from utils import gen_wrapped_env, show_video

# %%
env = gen_wrapped_env('MiniGrid-Empty-6x6-v0')
obs = env.reset()

agent_position = obs[0]

agent = QLearning(3, agent_position)

# %%
rewards = []
for ep in range(5000):
    done = False
    obs = env.reset()
    action = agent.act(obs)
    
    ep_rewards = 0
    while not done:
        next_obs, reward, done, info = env.step(action)

        next_action = agent.act(next_obs)

        agent.update(obs, action, reward, next_obs, next_action)
        
        ep_rewards += reward
        obs = next_obs
        action = next_action
    rewards.append(ep_rewards)
    if (ep+1) % 20 == 0:
        print("episode: {}, rewards: {}".format(ep+1, ep_rewards))
env.close()
# Out:
# episode: 20, rewards: 0
# episode: 40, rewards: 0
# episode: 60, rewards: 0
# episode: 80, rewards: 0
# episode: 100, rewards: 0
# episode: 120, rewards: 0
# episode: 140, rewards: 0
# episode: 160, rewards: 0
# episode: 180, rewards: 0
# episode: 200, rewards: 0
# episode: 220, rewards: 0
# episode: 240, rewards: 0
# episode: 260, rewards: 0
# episode: 280, rewards: 0
# episode: 300, rewards: 0
# episode: 320, rewards: 0
# episode: 340, rewards: 0
# episode: 360, rewards: 0
# episode: 380, rewards: 0
# episode: 400, rewards: 0
# episode: 420, rewards: 0
# episode: 440, rewards: 0
# episode: 460, rewards: 0
# episode: 480, rewards: 0
# episode: 500, rewards: 0
# episode: 520, rewards: 0
# episode: 540, rewards: 0
# episode: 560, rewards: 0.55
# episode: 580, rewards: 0
# episode: 600, rewards: 0.6759999999999999
# episode: 620, rewards: 0.766
# episode: 640, rewards: 0
# episode: 660, rewards: 0
# episode: 680, rewards: 0
# episode: 700, rewards: 0.17199999999999993
# episode: 720, rewards: 0.694
# episode: 740, rewards: 0.5680000000000001
# episode: 760, rewards: 0
# episode: 780, rewards: 0.2799999999999999
# episode: 800, rewards: 0
# episode: 820, rewards: 0.6579999999999999
# episode: 840, rewards: 0
# episode: 860, rewards: 0.6399999999999999
# episode: 880, rewards: 0
# episode: 900, rewards: 0
# episode: 920, rewards: 0.748
# episode: 940, rewards: 0
# episode: 960, rewards: 0
# episode: 980, rewards: 0
# episode: 1000, rewards: 0
# episode: 1020, rewards: 0.784
# episode: 1040, rewards: 0
# episode: 1060, rewards: 0.874
# episode: 1080, rewards: 0.118
# episode: 1100, rewards: 0
# episode: 1120, rewards: 0.42399999999999993
# episode: 1140, rewards: 0
# episode: 1160, rewards: 0
# episode: 1180, rewards: 0
# episode: 1200, rewards: 0.784
# episode: 1220, rewards: 0.82
# episode: 1240, rewards: 0
# episode: 1260, rewards: 0.694
# episode: 1280, rewards: 0.3879999999999999
# episode: 1300, rewards: 0
# episode: 1320, rewards: 0
# episode: 1340, rewards: 0
# episode: 1360, rewards: 0.838
# episode: 1380, rewards: 0
# episode: 1400, rewards: 0
# episode: 1420, rewards: 0.4059999999999999
# episode: 1440, rewards: 0
# episode: 1460, rewards: 0
# episode: 1480, rewards: 0.352
# episode: 1500, rewards: 0.748
# episode: 1520, rewards: 0.29799999999999993
# episode: 1540, rewards: 0.6399999999999999
# episode: 1560, rewards: 0.802
# episode: 1580, rewards: 0.784
# episode: 1600, rewards: 0.20799999999999996
# episode: 1620, rewards: 0
# episode: 1640, rewards: 0.766
# episode: 1660, rewards: 0.784
# episode: 1680, rewards: 0.73
# episode: 1700, rewards: 0.82
# episode: 1720, rewards: 0
# episode: 1740, rewards: 0
# episode: 1760, rewards: 0.766
# episode: 1780, rewards: 0.262
# episode: 1800, rewards: 0.802
# episode: 1820, rewards: 0.802
# episode: 1840, rewards: 0.73
# episode: 1860, rewards: 0.4059999999999999
# episode: 1880, rewards: 0.604
# episode: 1900, rewards: 0.838
# episode: 1920, rewards: 0
# episode: 1940, rewards: 0.766
# episode: 1960, rewards: 0.694
# episode: 1980, rewards: 0
# episode: 2000, rewards: 0.29799999999999993
# episode: 2020, rewards: 0.856
# episode: 2040, rewards: 0.2799999999999999
# episode: 2060, rewards: 0
# episode: 2080, rewards: 0.874
# episode: 2100, rewards: 0.802
# episode: 2120, rewards: 0.856
# episode: 2140, rewards: 0.244
# episode: 2160, rewards: 0.766
# episode: 2180, rewards: 0.694
# episode: 2200, rewards: 0
# episode: 2220, rewards: 0.514
# episode: 2240, rewards: 0.874
# episode: 2260, rewards: 0.17199999999999993
# episode: 2280, rewards: 0.838
# episode: 2300, rewards: 0.748
# episode: 2320, rewards: 0.6579999999999999
# episode: 2340, rewards: 0.37
# episode: 2360, rewards: 0.766
# episode: 2380, rewards: 0
# episode: 2400, rewards: 0
# episode: 2420, rewards: 0.874
# episode: 2440, rewards: 0
# episode: 2460, rewards: 0
# episode: 2480, rewards: 0
# episode: 2500, rewards: 0.622
# episode: 2520, rewards: 0.55
# episode: 2540, rewards: 0
# episode: 2560, rewards: 0.784
# episode: 2580, rewards: 0.5680000000000001
# episode: 2600, rewards: 0
# episode: 2620, rewards: 0.20799999999999996
# episode: 2640, rewards: 0
# episode: 2660, rewards: 0
# episode: 2680, rewards: 0.3879999999999999
# episode: 2700, rewards: 0.766
# episode: 2720, rewards: 0.856
# episode: 2740, rewards: 0
# episode: 2760, rewards: 0.748
# episode: 2780, rewards: 0
# episode: 2800, rewards: 0
# episode: 2820, rewards: 0.874
# episode: 2840, rewards: 0
# episode: 2860, rewards: 0.856
# episode: 2880, rewards: 0.4959999999999999
# episode: 2900, rewards: 0
# episode: 2920, rewards: 0.874
# episode: 2940, rewards: 0.15400000000000003
# episode: 2960, rewards: 0
# episode: 2980, rewards: 0
# episode: 3000, rewards: 0.5680000000000001
# episode: 3020, rewards: 0.694
# episode: 3040, rewards: 0
# episode: 3060, rewards: 0.73
# episode: 3080, rewards: 0.856
# episode: 3100, rewards: 0.3879999999999999
# episode: 3120, rewards: 0
# episode: 3140, rewards: 0
# episode: 3160, rewards: 0.478
# episode: 3180, rewards: 0
# episode: 3200, rewards: 0.874
# episode: 3220, rewards: 0.748
# episode: 3240, rewards: 0
# episode: 3260, rewards: 0
# episode: 3280, rewards: 0.6579999999999999
# episode: 3300, rewards: 0.17199999999999993
# episode: 3320, rewards: 0.15400000000000003
# episode: 3340, rewards: 0.838
# episode: 3360, rewards: 0.748
# episode: 3380, rewards: 0.838
# episode: 3400, rewards: 0
# episode: 3420, rewards: 0.802
# episode: 3440, rewards: 0
# episode: 3460, rewards: 0.514
# episode: 3480, rewards: 0
# episode: 3500, rewards: 0.856
# episode: 3520, rewards: 0
# episode: 3540, rewards: 0
# episode: 3560, rewards: 0.33399999999999996
# episode: 3580, rewards: 0
# episode: 3600, rewards: 0.6399999999999999
# episode: 3620, rewards: 0
# episode: 3640, rewards: 0
# episode: 3660, rewards: 0.694
# episode: 3680, rewards: 0.784
# episode: 3700, rewards: 0
# episode: 3720, rewards: 0.838
# episode: 3740, rewards: 0.82
# episode: 3760, rewards: 0.802
# episode: 3780, rewards: 0
# episode: 3800, rewards: 0.4059999999999999
# episode: 3820, rewards: 0.42399999999999993
# episode: 3840, rewards: 0.5680000000000001
# episode: 3860, rewards: 0
# episode: 3880, rewards: 0.42399999999999993
# episode: 3900, rewards: 0.6759999999999999
# episode: 3920, rewards: 0.44199999999999995
# episode: 3940, rewards: 0
# episode: 3960, rewards: 0
# episode: 3980, rewards: 0
# episode: 4000, rewards: 0
# episode: 4020, rewards: 0
# episode: 4040, rewards: 0
# episode: 4060, rewards: 0.622
# episode: 4080, rewards: 0
# episode: 4100, rewards: 0.694
# episode: 4120, rewards: 0
# episode: 4140, rewards: 0.874
# episode: 4160, rewards: 0.42399999999999993
# episode: 4180, rewards: 0.766
# episode: 4200, rewards: 0.136
# episode: 4220, rewards: 0.136
# episode: 4240, rewards: 0
# episode: 4260, rewards: 0.856
# episode: 4280, rewards: 0.118
# episode: 4300, rewards: 0
# episode: 4320, rewards: 0.874
# episode: 4340, rewards: 0
# episode: 4360, rewards: 0.17199999999999993
# episode: 4380, rewards: 0.802
# episode: 4400, rewards: 0
# episode: 4420, rewards: 0
# episode: 4440, rewards: 0.20799999999999996
# episode: 4460, rewards: 0.45999999999999996
# episode: 4480, rewards: 0.586
# episode: 4500, rewards: 0.712
# episode: 4520, rewards: 0.17199999999999993
# episode: 4540, rewards: 0.73
# episode: 4560, rewards: 0.712
# episode: 4580, rewards: 0
# episode: 4600, rewards: 0.784
# episode: 4620, rewards: 0.712
# episode: 4640, rewards: 0
# episode: 4660, rewards: 0.42399999999999993
# episode: 4680, rewards: 0
# episode: 4700, rewards: 0.802
# episode: 4720, rewards: 0.82
# episode: 4740, rewards: 0.604
# episode: 4760, rewards: 0.838
# episode: 4780, rewards: 0
# episode: 4800, rewards: 0
# episode: 4820, rewards: 0
# episode: 4840, rewards: 0
# episode: 4860, rewards: 0
# episode: 4880, rewards: 0.622
# episode: 4900, rewards: 0
# episode: 4920, rewards: 0
# episode: 4940, rewards: 0.514
# episode: 4960, rewards: 0
# episode: 4980, rewards: 0
# episode: 5000, rewards: 0.784

# %%
{s:np.round(q, 5).tolist() for s, q in agent.q_values.items()}
# Out:
# {0: [0.03904, 0.03912, 0.04478],
#  3: [0.02265, 0.02196, 0.03316],
#  12: [0.06329, 0.06366, 0.07137],
#  15: [0.01526, 0.01904, 0.09523],
#  27: [0.03885, 0.05522, 0.20192],
#  6: [0.02418, 0.02352, 0.03446],
#  24: [0.0869, 0.08699, 0.09592],
#  36: [0.10339, 0.10325, 0.11115],
#  18: [0.03366, 0.02723, 0.12812],
#  30: [0.06034, 0.04337, 0.2774],
#  39: [0.36232, 0.35877, 0.43248],
#  9: [0.03522, 0.03522, 0.03727],
#  42: [0.46285, 0.47469, 0.57318],
#  21: [0.12882, 0.12123, 0.15318],
#  33: [0.23449, 0.2584, 0.34039],
#  45: [0.0, 0.0, 0.0]}

# %%
show_video()
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
pd.Series(rewards).to_csv('./logs/rewards_qlearning.csv')
# Out:
# /home/johnny/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
sarsa_logs = pd.read_csv('./logs/rewards_sarsa.csv', index_col=False).iloc[:, 1]
q_logs = pd.read_csv('./logs/rewards_qlearning.csv', index_col=False).iloc[:, 1]

# %%
plt.figure(figsize=(16, 8))
plt.plot(q_logs.cumsum() / (pd.Series(np.arange(q_logs.shape[0]))+1), label="QLearning")
plt.plot(sarsa_logs.cumsum() / (pd.Series(np.arange(sarsa_logs.shape[0]))+1), label="SARSA")
plt.legend()
